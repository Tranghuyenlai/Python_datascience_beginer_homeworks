# %%
#1.Nhập điểm in ra học lực học sinh. (giỏi 8-10, khá 6.5-8, trung bình 5-6.5, còn lại yếu).
diem = float(input('diem: '))
if diem <0 or diem > 10:
  print('Điểm không có thực')
elif 8<= diem <= 10:
  print('Học lực giỏi')
elif 6.5<= diem:
  print('Học lực khá')
elif 5<= diem:
  print('Học lực trung bình')
else:
  print('Học lực yếu')
# Out:
# diem: 4
# Học lực yếu

# %%
#2. Nhập vào 1 năm ( số nguyên ), kiểm tra xem đấy có phải năm nhuận không.
year = int(input('year: '))
if (year % 4 == 0 and year % 100 != 0) or year % 4 == 0:
  print('{} la nam nhuan'.format(year))
else:
  print('{} khong phai nam nhuan'.format(year))
# Out:
# year: 2022
# 2022 khong phai nam nhuan

# %%
#3) Nhập vào 1 tháng in ra số ngày trong tháng. 
month = int(input('month: '))
if month == 2:
  year = int(input('year: '))
  if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
      print('Tháng {} của năm {} có 29 ngày'.format(month,year))
  else:
      print('Tháng {} của năm {} có 28 ngày'.format(month,year))
elif month == 4 or month == 6 or month == 9 or month == 11:
  print ('Tháng {} có 30 ngày'.format(month))
else:
  print ('Tháng {} có 31 ngày'.format(month))
# Out:
# month: 2
# year: 2022
# Tháng 2 của năm 2022 có 28 ngày

# %%
#4) Cho người dùng nhập vào 3 số a, b, c, in ra giá trị lớn nhất và các số lớn nhất.
a = float(input('a = '))
b = float(input('b = '))
c = float(input('c = '))
m = a

if m == b != c:
  print('Giá trị lớn nhất là {}. Các số lớn nhất là a,b'.format(a))
elif m == c != b:
  print('Giá trị lớn nhất là {}. Các số lớn nhất là a,c'.format(a))
elif m == b == c:
  print('Giá trị lớn nhất là {}. Các số lớn nhất là a,b,c'.format(a))
elif m < b:
  if b == c:
    print('Giá trị lớn nhất là {}. Các số lớn nhất là b,c'.format(b))
  else:
    print('Giá trị lớn nhất là {}. Số lớn nhất là b'.format(b))
elif m < c:
  if c == b:
    print('Giá trị lớn nhất là {}. Các số lớn nhất là b,c'.format(c))
  else:
    print('Giá trị lớn nhất là {}. Số lớn nhất là c'.format(c))
else:
  print('Giá trị lớn nhất là {}. Số lớn nhất là a'.format(a))
# Out:
# a = 34
# b = 34
# c = 34
# Giá trị lớn nhất là 34.0. Các số lớn nhất là a,b,c

# %%
#4. (Trung fixed)
a = float(input("Nhập số a: "))
b = float(input("Nhập số b: "))
c = float(input("Nhập số c: "))
max = a
if b > max:
  max = b
if c > max:
  max = c
print(f"Giá trị lớn nhất là {max}")

max_letter = ""
if a == max:
  max_letter = max_letter + "a "
if b == max:
  max_letter = max_letter + "b "
if c == max:
  max_letter = max_letter + "c "

print(f"Số lớn nhất là {max_letter}")
# Out:
# Nhập số a: 3
# Nhập số b: 3
# Nhập số c: 3
# Giá trị lớn nhất là 3.0
# Số lớn nhất là a b c

# %%
#4) Fix
a = float(input('a = '))
b = float(input('b = '))
c = float(input('c = '))
max = a
if max < b:
  max = b
if max < c:
  max = c
print('Max = {}'.format(max))

max_name = ''
if max == a:
  max_name = max_name + 'a '
if max == b:
  max_name = max_name + 'b '
if max == c:
  max_name = max_name + 'c 1'
print('So lon nhat la {}'.format(max_name))
# Out:
# a = 123
# b = 123
# c = 23
# Max = 123.0
# So lon nhat la a b

# %%
#5.Nhập vào a, b. Giải và biện luận tìm nghiệm phương trình ax + b = 0.
a = float(input('a = '))
b = float(input('b = '))
if a != 0:
  x = float((-b)/a)
  print('Với a = {0}, b = {1} phương trình trở thành {0}x + {1} = 0 <=> x = (-{1})/{0} <=> x = {2}'.format(a,b,x))
  print('Phương trình có nghiệm duy nhất x = {}'.format(x))
elif a == 0:
  if b == 0:
    print('Với a = {0}, b = {1} phương trình trở thành {0}x + {1} = 0 <=> {0}x = {1}'.format(a,b,x))
    print('Phương trình có nghiệm đúng với mọi x')
  else:
    print('Với a = {0}, b = {1} phương trình trở thành {0}x + {1} = 0 <=> {0}x = -{1}'.format(a,b))
    print('Phương trình vô nghiệm')
# Out:
# a = 1
# b = 2
# Với a = 1.0, b = 2.0 phương trình trở thành 1.0x + 2.0 = 0 <=> x = (-2.0)/1.0 <=> x = -2.0
# Phương trình có nghiệm duy nhất x = -2.0

# %%
#6. Nhập vào a,b,c. Giải và biện luận tìm nghiệm phương trình ax^2 + bx + c = 0.
import math 
a = float(input('a = '))
b = float(input('b = '))
c = float(input('c = '))
if a == 0:
  print('Với a = {0}, b = {1}, c = {2}, \nphương trình trở thành phương trình bậc 2: bx + c = 0'.format(a,b,c)) 
  if b != 0:
    x = float((-c)/b)
    print('Ta có phương trình: {1}x + {2} = 0 <=> x = (-{2})/{1} <=> x = {3}'.format(a,b,c,x))
    print('Phương trình có nghiệm duy nhất x = {}'.format(x))
  elif b == 0:
    if c == 0:
      print('Ta có phương trình: \n{1}x + {2} = 0 <=> {1}x = {2}'.format(a,b,c))
      print('Kết luận: Phương trình có nghiệm đúng với mọi x')
    else:
      print('Ta có phương trình: \n{1}x + {2} = 0 <=> {1}x = -{2}'.format(a,b,c))
      print('Kết luận: Phương trình vô nghiệm')
if a != 0:
  delta = float(b**2 - 4*a*c)
  print('Với a = {0}, b = {1}, c = {2}, \nPhương trình trở thành {0}x^2 + {1}x + {2} = 0'.format(a,b,c))
  if delta < 0:
    print('Ta có delta = b^2 - 4ac => delta = ({1})^2 - 4*{0}*{2} = {3}'.format(a,b,c,delta))
    print('Do delta = {} <  0. Kết luận: Phương trình vô nghiệm'.format(delta))
  elif delta == 0:
    x = -b/(2*a)
    print('Ta có delta = b^2 - 4ac => delta = ({1})^2 - 4*{0}*{2} = {3}'.format(a,b,c,delta))
    print('Do delta = {0}. Kết luận: Phương trình lúc này có nghiệm kép x1 = x2 = {1}'.format(delta,x))
  else:
    sqrt_delta = math.sqrt(delta)
    x1 = ((-b) + float(sqrt_delta))/(2*a)
    x2 = ((-b) - float(sqrt_delta))/(2*a)
    print('Ta có delta = b^2 - 4ac = ({1})^2 - 4*{0}*{2} = {3}'.format(a,b,c,delta))
    print('Do delta = {} >  0. Kết luận: Phương trình có hai nghiệm phân biệt: '.format(delta))
    print('x1 = (-(b) + squareroot(delta))/2(a) = (-{1} + {2})/(2*{0}) = {3}'.format(a,b,sqrt_delta,x1))
    print('x2 = (-(b) - squareroot(delta))/2(a) = (-{1} - {2})/(2*{0}) = {3}'.format(a,b,sqrt_delta,x2))
# Out:
# a = 0
# b = 2
# c = 0
# Với a = 0.0, b = 2.0, c = 0.0,
# phương trình trở thành phương trình bậc 2: bx + c = 0
# Ta có phương trình: 2.0x + 0.0 = 0 <=> x = (-0.0)/2.0 <=> x = -0.0
# Phương trình có nghiệm duy nhất x = -0.0

# %%
#7) Nhập vào 1 kí tự. Kiểm tra xem kí tự đó là chữ thường (a-z) , hay chữ hoa (A-Z), hay là số (0-9), hay là kí tự đặc biệt (còn lại).
character = input('character: ')
upper_text = character.upper()
lower_text = character.lower()
if character == upper_text != lower_text:
  print('Ky tu \'{}\' la chu hoa'.format(character))
elif character == lower_text != upper_text:
  print('Ky tu \'{}\' la chu thuong'.format(character))
else:
  if '0' <= character <= '9':
    print('Ky tu \'{}\' la so'.format(character))
  else:
    print('Ky tu \'{}\' la ky tu dac biet'.format(character))
# Out:
# character: ?
# Ky tu '?' la ky tu dac biet

# %%
#7) (fix) Nhập vào 1 kí tự. Kiểm tra xem kí tự đó là chữ thường (a-z) , hay chữ hoa (A-Z), hay là số (0-9), hay là kí tự đặc biệt (còn lại).

# %%
#8 ) Nhập độ dài 3 cạnh 1 tam giác, kiểm tra độ dài có hợp lệ không? nếu có, kiểm tra xem có phải tam giác đều/cân/vuông/vuông cân không?
a = float(input('canh_1: '))
b = float(input('canh_2: '))
c = float(input('canh_3: '))
if (a + b > c) and (a + c > b) and (b + c > a):
  if a == b and b == c: 
    print('{}, {}, {} là ba cạnh lần lượt của một tam giác đều'.format(a, b, c))
  elif a == b or a == c or b == c:
    if a*a == b*b + c*c or b*b == a*a + c*c or c*c == a*a + b*b:
      print('{}, {}, {} là ba cạnh lần lượt của một tam giác vuông cân'.format(a, b, c))
    else:
      print('{}, {}, {} là ba cạnh lần lượt của một tam giác tam giác cân'.format(a, b, c))
  elif a*a == b*b + c*c or b*b == a*a + c*c or c*c == a*a + b*b:
    print('{}, {}, {} là ba cạnh lần lượt của một tam giác vuông'.format(a, b, c))
  else:
    print('{}, {}, {} là ba cạnh lần lượt của một tam giác'.format(a, b, c))
else:
  print('{}, {}, {} không phải là ba cạnh của một tam giác'.format(a, b, c))
# Out:
# canh_1: 1
# canh_2: 1
# canh_3: 3
# 1.0, 1.0, 3.0 không phải là ba cạnh của một tam giác

# %%
#9.Nhập vào số điện output giá tiền, biết rằng: 50 số đầu tiên có giá 3.000/1 số, 
#100 số tiếp theo có giá 4.000/1 số, 100 số tiếp theo 5.000/1 số và từ 250 số trở đi thì giá là 10.000/1 số. 
#VD: 75 số thì giá tiền là 50000 + 25000 
so_dien = float(input('so dien: '))
tien_1 = int(3000) #0<so_dien<=50
tien_2 = int(4000) #50<so_dien<=150
tien_3 = int(5000) #151 < so_dien <= 250
tien_4 = int(10000) # 250<= so_dien
if so_dien < 0:
  print('Số điện {} nhập vào không hợp lệ'.format(so_dien))
else:
  if 0 <= so_dien <= 50:
    tien_dien = so_dien*tien_1
  elif 50< so_dien <= 150:
    tien_dien = 50*tien_1 + (so_dien - 50)*tien_2
  elif 150< so_dien <= 250:
    tien_dien = 50*tien_1 + 100*tien_2 + (so_dien - 150)*tien_3
  elif so_dien > 250:
    tien_dien = 50*tien_1 + 100*tien_2 + 100*tien_3 + (so_dien - 250)*tien_4
  print('Với số điện {} đã sử dụng, tiền điện cần phải trả là {}'.format(so_dien, tien_dien))
# Out:
# so dien: 75
# Với số điện 75.0 đã sử dụng, tiền điện cần phải trả là 250000.0
