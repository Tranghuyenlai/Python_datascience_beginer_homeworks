# %%
name = 'Minh'
age = 12

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(12))
# Out:
# <class 'int'>

# %%
year = input('year')
print(type(year))
# Out:
# year2000
# <class 'str'>

# %%
 check = True
print(type(check))
# Out:
# <class 'bool'>

# %%
int(year)
# Out:
# 2000

# %%
int('x3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c32056e1fdf8> in <module>
# ----> 1 int('x3')
#
# ValueError: invalid literal for int() with base 10: 'x3'

# %%
# built in library
import math

# %%
x = math.exp(2)

# %%
print(x)
# Out:
# 7.38905609893065

# %%
print(type(math.sqrt(16)), math.sqrt(16))
# Out:
# <class 'float'> 4.0

# %%
x = int(input('x = '))
if x % 3 == 0:
  print('{} chia het cho 3'.format(x))
else:
  print('{} khong chia het cho 3'.format(x))
# Out:
# x = 15
# 15 chia het cho 3

# %%
x = 4
print(int(x), x)
# Out:
# 4 4

# %%
x = int(input('x = '))

x_sqrt = math.sqrt(x)

print(x_sqrt, int(x_sqrt))

# if type(x_sqrt) == int:
if x_sqrt == int(x_sqrt):
  print('{} la so chinh phuong'.format(x))
else:
  print('{} khong la so chinh phuong'.format(x))
# Out:
# x = 16
# 4.0 4
# 16 la so chinh phuong

# %%
x = 5
if x % 3 == 0:
  print('{} chia het cho 3'.format(x))

x = 4

# %%
x = 5
if True:
  x > 0
  print('a positive')
# Out:
# a positive

# %%
mark = float(input('mark: '))

# if 8 <= mark and mark <= 10:
if mark < 0 or mark > 10:
  print('ko hop le')
elif 8 <= mark:
  print('gioi')
elif 6.5 <= mark:
  print('kha')
elif 5 <= mark:
  print('tb')
else:
  print('yeu')
# Out:
# mark: 6
# tb

# %%
year = int(input('year: '))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
  print('nam nhuan')
else:
  print('khong phai nam nhuan')
# Out:
# year: 1996
# nam nhuan

# %%
year = 1900
if year % 4 == 0:
  if year % 400 == 0:
    print('nam nhuan')
  elif year % 100 == 0:
    print('khong phai nam nhuan')
  else:
    print('nam nhuan')
else:
  print('khong phai nam nhuan')
# Out:
# khong phai nam nhuan

# %% [markdown]
# Nhập 3 số a, b, c. In ra giá trị lớn nhất
#
# a = 1, b = 2, c = 3 -> giá trị lớn nhất là 3
#
# a = 7, b = 7, c = 3 -> giá trị lớn nhất là 7

# %%
a = 7
b = 2
c = 10

m = a

if b > m:
  m = b

# m = max(a, b)

if c > m:
  m = c

max(1, 2, 1)
# Out:
# 2
