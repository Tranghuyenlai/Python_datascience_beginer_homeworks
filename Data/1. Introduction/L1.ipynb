# %% [markdown]
# **print**: câu lệnh print giúp in giá trị ra màn hình
#
#
#
# *   print(5) -> in 5 ra màn hình
# *   print('hello') -> in chữ hello ra màn hình

# %%
print('hello')
# Out:
# hello

# %%
print('Minh')
# Out:
# Minh

# %%
print(3)
# Out:
# 3

# %% [markdown]
# BT1: tạo 1 file notebook, in ra màn hình chữ hello world

# %%
name = 'Minh'

# %%
print('name')
# Out:
# name

# %%
print(name) # print('Minh') -> Minh
# Out:
# Minh

# %%
print(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5f7a7c5b2c60> in <module>
# ----> 1 print(age)
#
# NameError: name 'age' is not defined

# %%
print('9')
# Out:
# 9

# %%
print(9)
# Out:
# 9

# %%
name = 'Thanh'

# %%
print('Hello ' + name + '.') # 'Hello ' + 'Thanh' -> Hello Thanh
# Out:
# Hello Thanh.

# %%
'''
print('Hi')
print('Hello')
'''
print('Hi')
# Out:
# Hi

# %% [markdown]
# variable = input(string) -> variable luôn là dạng chuỗi
#
# in string ra màn hình và đợi người dùng nhập vào thông tin, giá trị của thông tin người dùng nhập sẽ được lưu vào viến variable

# %%
name = input('your name: ')
# Out:
# your name: Anh

# %%
print(name)
# Out:
# Anh

# %%
name = input('name: ')
city = input('city: ')
# Out:
# name: Minh
# city: Ha Noi

# %%
print('chào bạn '+name + ', đến từ ' + city)
# Out:
# chào bạn Minh, đến từ Ha Noi

# %% [markdown]
# int: integer, số nguyen
#
# str: string, chuỗi
#
# ép kiểu: new_type(variable) -> ép variable sang kiểu dữ liệu new_type

# %%
'''
year = input('year: ')
year = int(year)
'''
year = int(input('year: '))
age = 2022 - year

age = 2022 - year
print('you are ' + str(age) + ' years old')
# Out:
# year: 2000
# you are 22 years old

# %%
year = input('year: ')
age = 2022 - int(year)

age = 2022 - year
print('you are ' + str(age) + ' years old')
# Out:
# year: 2000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9e062ab53ced> in <module>
#       2 age = 2022 - int(year)
#       3
# ----> 4 age = 2022 - year
#       5 print('you are ' + str(age) + ' years old')
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
'a' + 'b'
# Out:
# 'ab'

# %%
'a' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-833c9ffc6e69> in <module>
# ----> 1 'a' + 4
#
# TypeError: can only concatenate str (not "int") to str
